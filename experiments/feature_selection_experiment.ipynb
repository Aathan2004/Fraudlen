# %%
from pathlib import Path
import pandas as pd

# Project root
PROJECT_ROOT = Path(r"C:\Users\suriy\Desktop\healthcare_fraud")

# Feature importance file
importance_path = (
    PROJECT_ROOT
    / "experiments"
    / "outputs"
    / "feature_importance_300.csv"
)

print("Current notebook directory:")
print(Path.cwd())

print("\nLooking for:")
print(importance_path)

print("\nFile exists:", importance_path.exists())

# Load the feature importance results
importance_df = pd.read_csv(importance_path)

print("\nTotal features:", len(importance_df))

importance_df.head(20)
# Out:
# Current notebook directory:
# c:\Users\suriy\Desktop\healthcare_fraud\experiments
#
# Looking for:
# C:\Users\suriy\Desktop\healthcare_fraud\experiments\outputs\feature_importance_300.csv
#
# File exists: True
#
# Total features: 300
#     Rank                                       Feature  Importance
# 0      1                     count_ClaimID_perProvider   12.506232
# 1      2   count_ClaimID_perProviderClmProcedureCode_4    8.578028
# 2      3   count_ClaimID_perProviderClmProcedureCode_3    7.905803
# 3      4                mean_Hospital_Days_perProvider    6.504666
# 4      5            mean_DeductibleAmtPaid_perProvider    5.866651
# 5      6     mean_IPAnnualReimbursementAmt_perProvider    5.437650
# 6      7   count_ClaimID_perProviderClmProcedureCode_5    5.355179
# 7      8                   mean_Claim_Days_perProvider    5.215276
# 8      9       mean_InscClaimAmtReimbursed_perProvider    5.074442
# 9     10                          mean_Age_perProvider    4.591569
# ...

# %%
pd.set_option("display.max_rows", 300)
pd.set_option("display.max_colwidth", 100)

importance_df
# Out:
#      Rank                                                 Feature  \
# 0       1                               count_ClaimID_perProvider
# 1       2             count_ClaimID_perProviderClmProcedureCode_4
# 2       3             count_ClaimID_perProviderClmProcedureCode_3
# 3       4                          mean_Hospital_Days_perProvider
# 4       5                      mean_DeductibleAmtPaid_perProvider
# 5       6               mean_IPAnnualReimbursementAmt_perProvider
# 6       7             count_ClaimID_perProviderClmProcedureCode_5
# 7       8                             mean_Claim_Days_perProvider
# 8       9                 mean_InscClaimAmtReimbursed_perProvider
# 9      10                                    mean_Age_perProvider
# 10     11                  mean_OPAnnualDeductibleAmt_perProvider
# 11     12                  mean_IPAnnualDeductibleAmt_perProvider
# 12     13            count_ClaimID_perProviderClmDiagnosisCode_10
# ...
